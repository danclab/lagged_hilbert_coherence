# %%
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import scipy
from fooof import FOOOF
from lagged_coherence import *
import mne

# %%
freq_lims = [5,100]
lags = np.arange(1,4,.1)

def many_is_in(multiple, target):
    check_ = []
    for i in multiple:
        check_.append(i in target)
    return any(check_)

sens = ["MLC1", "MLC25", "MLC32", "MLC42", "MLC54", "MLC55", "MLC63"]

base_dir='/home/mszul/datasets/explicit_implicit_beta/derivatives/processed/'
out_dir='/home/bonaiuto/lagged_hilbert_coherence/output/explicit-implicit/'

# %%
sub_paths=sorted(glob.glob(os.path.join(base_dir,'sub-*')))
for sub_idx, sub_path in enumerate(sub_paths):
    sub=os.path.split(sub_path)[-1]
    sub_out_path=os.path.join(out_dir,sub)
    if not os.path.exists(sub_out_path):
        os.mkdir(sub_out_path)

    epo_paths=sorted(glob.glob(os.path.join(sub_path,'{}-*-epo.fif'.format(sub))))
    for epo_path in epo_paths:
        block_num=os.path.split(epo_path)[-1].split('-')[2]
        epo_type=os.path.split(epo_path)[-1].split('-')[3]
        epo = mne.read_epochs(epo_path)
        epo = epo.pick_types(meg=True, ref_meg=False,misc=False)
        
        channels_used = [i for i in epo.info.ch_names if many_is_in(["MLC"], i)]
        channels_used = [i for i in channels_used if not many_is_in(sens, i)]

        fs=epo.info['sfreq']
        epo_data=epo.get_data()
        epo_data=np.moveaxis(epo_data,[0,1,2],[1,0,2])

        psd=[]
        lc=[]
        chs=[]
        for ch_idx in range(epo_data.shape[0]):
            if epo.info['ch_names'][ch_idx] in channels_used:
                data=epo_data[ch_idx,:,:]
                chs.append(ch_idx)

                freqs,ch_psd=scipy.signal.welch(data, fs=fs, window='hann', 
                                            nperseg=int(fs), noverlap=int(fs/2), nfft=int(fs*2), detrend='constant', 
                                            return_onesided=True, scaling='density', axis=- 1, average='mean')
                f_idx=(freqs>=freq_lims[0]) & (freqs<=freq_lims[-1])
                freqs=freqs[f_idx]
                ch_psd=np.mean(ch_psd[:,f_idx],axis=0)

                ch_lc=lagged_hilbert_coherence(data, freqs, lags, fs, n_jobs=20)

                psd.append(ch_psd)
                lc.append(ch_lc)
        chs=np.array(chs)
        psd=np.array(psd)
        lc=np.array(lc)

        out_fname=os.path.join(sub_out_path,'{}-{}-{}.npz'.format(sub,block_num,epo_type))
        np.savez(out_fname, 
                 **{          
                     'chs': chs,
                     'freqs': freqs,
                     'lags': lags,
                     'psd': psd,
                     'lc': lc
                    })
# Out:
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-002-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-002-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-003-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-003-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-004-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-004-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-005-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-005-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-006-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-006-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-007-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-007-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-008-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-008-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-009-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-101/sub-101-009-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-002-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-002-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-003-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-003-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-004-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-004-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-005-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-005-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-006-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-006-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-007-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-007-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-008-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-008-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-009-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-102/sub-102-009-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-002-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-002-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-003-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-003-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-004-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-004-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-005-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-005-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-006-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-006-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-007-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-007-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-008-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-008-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-009-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-103/sub-103-009-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-002-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-002-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-003-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-003-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-004-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-004-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-005-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-005-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-006-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-006-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-007-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-007-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-008-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-008-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-009-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-106/sub-106-009-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-002-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-002-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-003-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-003-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-004-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-004-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-005-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-005-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-006-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-006-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-007-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-007-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-008-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-008-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-009-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-107/sub-107-009-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-002-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-002-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-003-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-003-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-004-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-004-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 53 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-005-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-005-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-006-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-006-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-007-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-007-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-008-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-008-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-009-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-108/sub-108-009-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 52 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-109/sub-109-002-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-109/sub-109-002-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-109/sub-109-003-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-109/sub-109-003-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-109/sub-109-004-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-109/sub-109-004-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-109/sub-109-005-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-109/sub-109-005-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 54 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-109/sub-109-006-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-109/sub-109-006-visual-epo.fif ...
#     Read 5 compensation matrices
# ...
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-143/sub-143-008-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-143/sub-143-009-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-143/sub-143-009-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-002-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-002-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-003-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-003-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-004-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-004-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-005-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-005-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-006-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-006-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-007-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-007-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-008-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-008-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-009-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-144/sub-144-009-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-002-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-002-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 55 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-003-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-003-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-004-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-004-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-005-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-005-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-006-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-006-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-007-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-007-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-008-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-008-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-009-motor-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    1500.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
# Reading /home/mszul/datasets/explicit_implicit_beta/derivatives/processed/sub-145/sub-145-009-visual-epo.fif ...
#     Read 5 compensation matrices
#     Found the data of interest:
#         t =   -1000.00 ...    2000.00 ms
#         5 CTF compensation matrices available
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Removing 5 compensators from info because not all compensation channels were picked.
